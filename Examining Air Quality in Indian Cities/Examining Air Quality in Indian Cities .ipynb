# %% [markdown]
# **Data Source**: Air pollution is a significant concern in India. Central Pollution Control Board (CPCB) website or platforms like OpenAQ

# %% [markdown]
# **EDA Focus:**

# %% [markdown]
# 1. Analyze trends in air pollutants PM2.5, N02, S02 over time.
# 2. Compare air quality across different cities.
# 3. Identify seasonal patterns and potential correlations with weather data.
# 4. Visualize pollution levels using line graphs, heatmaps, and time series plots.

# %% [markdown]
# **Pandas Library Usage:**

# %% [markdown]
# Data cleaning and preprocessing to handle missing values. df.resample() for time-based analysis (e.g., daily or monthly averages). df.plot() for
# creating various plot types.

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\Ganesh Mogaveera\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
#Sample air QUality data for indian cities (Replace with date from CPCB)

# %%
import pandas as pd

data = {
    "city": ["Delhi", "Mumbai", "Kolkata", "Chennai", "Bangalore", "Hyderabad", "Pune", "Ahmedabad", "Jaipur", "Lucknow"],
    "date": pd.to_datetime(["2023-01-15"] * 10),
    "pm25": [250, 120, 180, 90, 70, 150, 110, 160, 200, 140],
    "no2": [80, 50, 60, 40, 30, 79, 45, 65, 99, 55],
    "so2": [30, 20, 25, 15, 10, 25, 38, 18, 28, 35]
}

# Convert to DataFrame

air_quality_df = pd.DataFrame(data)

# %%
#1.Basic Data Exploration
print(air_quality_df.head())
# Out:
#         city       date  pm25  no2  so2
# 0      Delhi 2023-01-15   250   80   30
# 1     Mumbai 2023-01-15   120   50   20
# 2    Kolkata 2023-01-15   180   60   25
# 3    Chennai 2023-01-15    90   40   15
# 4  Bangalore 2023-01-15    70   30   10

# %%
print(air_quality_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   city    10 non-null     object
#  1   date    10 non-null     datetime64[ns]
#  2   pm25    10 non-null     int64
#  3   no2     10 non-null     int64
#  4   so2     10 non-null     int64
# dtypes: datetime64[ns](1), int64(3), object(1)
# memory usage: 532.0+ bytes
# None

# %%
#2. PM2.5 Analysis
average_pm25 = air_quality_df['pm25'].mean()
print("\nAverage PM2.5 across cities:", average_pm25)
# Out:
# Average PM2.5 across cities: 147.0

# %%
#3. City with Highest NO2 Levels
city_highest_no2 = air_quality_df.loc[air_quality_df['no2'].idxmax(),'city']
print("\ncity with highest NO2 levels:", city_highest_no2)
# Out:
# city with highest NO2 levels: Jaipur

# %%
#4.  Correlation between pollutants
correlation_pm25_no2 = air_quality_df['pm25'].corr(air_quality_df['no2'])
print("\nCorrelation between PM2.5 and NO2:", correlation_pm25_no2)
# Out:
# Correlation between PM2.5 and NO2: 0.8437605572472652

# %% [markdown]
# ### Bar Chart of PM2.5 Levels by city

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='city',y='pm25', data= air_quality_df)
plt.title ('pm2.5 Levels by City')
plt.xlabel("City")
plt.ylabel("PM2.5")
plt.xticks(rotation= 45)
plt.show()

# %% [markdown]
# ### Scatter Plot of PM2.5 vs NO2

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x='pm25',y = 'no2', data=air_quality_df, hue='city')
plt.title('PM2.5 vs NO2 Levels')
plt.xlabel('PM2.5')
plt.ylabel('NO2')
plt.show()
